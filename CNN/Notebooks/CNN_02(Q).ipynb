# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
import os

gpus = tf.config.experimental.list_physical_devices('GPU')

for gpu in gpus:
    tf.config.experimental.list_set_memory_growth(gpu, True)

#tf.data.Dataset??

# %% [markdown]
# https://www.youtube.com/watch?v=jztwpsIzEGc

# %%
# Out:
# Collecting tftables
#   Downloading tftables-1.1.2-py2.py3-none-any.whl (12 kB)
# Collecting multitables
#   Downloading multitables-2.0.1-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: tensorflow in c:\users\yoris\anaconda3\lib\site-packages (from tftables) (2.11.0)
# Requirement already satisfied: numpy!=1.10.1 in c:\users\yoris\anaconda3\lib\site-packages (from tftables) (1.21.5)
# Requirement already satisfied: tables in c:\users\yoris\anaconda3\lib\site-packages (from multitables->tftables) (3.6.1)
# Requirement already satisfied: wrapt in c:\users\yoris\anaconda3\lib\site-packages (from multitables->tftables) (1.14.1)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\yoris\anaconda3\lib\site-packages (from multitables->tftables) (1.0.3)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow->tftables) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (22.12.6)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (14.0.6)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (2.11.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (3.19.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (3.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (0.28.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (1.3.0)
# Requirement already satisfied: packaging in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (63.4.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (1.51.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (2.1.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\yoris\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->tftables) (4.3.0)
# Requirement already satisfied: numexpr>=2.6.2 in c:\users\yoris\anaconda3\lib\site-packages (from tables->multitables->tftables) (2.8.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\yoris\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow->tftables) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\yoris\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\yoris\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\yoris\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (2.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\yoris\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\yoris\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (1.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\yoris\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow->tftables) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\yoris\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\yoris\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\yoris\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\yoris\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yoris\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yoris\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\yoris\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yoris\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (1.26.11)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\yoris\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\yoris\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->tftables) (3.2.2)
# Installing collected packages: multitables, tftables
# Successfully installed multitables-2.0.1 tftables-1.1.2
# Note: you may need to restart the kernel to use updated packages.
